# %% [markdown]
# https://huggingface.github.io/candle/guide/installation.html

# %%
# !git clone https://github.com/huggingface/candle.git
# Out:
# Cloning into 'candle'...
# remote: Enumerating objects: 22958, done.
# remote: Counting objects: 100% (633/633), done.
# remote: Compressing objects: 100% (228/228), done.
# remote: Total 22958 (delta 486), reused 405 (delta 405), pack-reused 22325 (from 3)
# Receiving objects: 100% (22958/22958), 12.98 MiB | 17.16 MiB/s, done.
# Resolving deltas: 100% (15509/15509), done.

# %%
# %cd candle
# Out:
# /content/candle

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y --default-toolchain nightly

import os
os.environ['PATH'] += ":/root/.cargo/bin"

# !rustc --version
# !cargo --version
# Out:
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# info: syncing channel updates for 'nightly-x86_64-unknown-linux-gnu'
# info: latest update on 2025-08-21, rust version 1.91.0-nightly (040a98af7 2025-08-20)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-docs'
# info: downloading component 'rust-std'
# info: downloading component 'rustc'
#  80.2 MiB /  80.2 MiB (100 %)  68.9 MiB/s in  1s
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
#  10.3 MiB /  10.3 MiB (100 %)   9.4 MiB/s in  1s
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  21.8 MiB /  21.8 MiB (100 %)   3.1 MiB/s in  7s
# info: installing component 'rust-std'
#  28.0 MiB /  28.0 MiB (100 %)   6.6 MiB/s in  4s
# info: installing component 'rustc'
#  80.2 MiB /  80.2 MiB (100 %)   7.8 MiB/s in  9s
# info: installing component 'rustfmt'
# info: default toolchain set to 'nightly-x86_64-unknown-linux-gnu'
#
#   nightly-x86_64-unknown-linux-gnu installed - rustc 1.91.0-nightly (040a98af7 2025-08-20)
#
#
# Rust is installed now. Great!
#
# To get started you may need to restart your current shell.
# This would reload your PATH environment variable to include
# Cargo's bin directory ($HOME/.cargo/bin).
#
# To configure your current shell, you need to source
# the corresponding env file under $HOME/.cargo.
#
# This is usually done by running one of the following (note the leading DOT):
# . "$HOME/.cargo/env"            # For sh/bash/zsh/ash/dash/pdksh
# source "$HOME/.cargo/env.fish"  # For fish
# source $"($nu.home-path)/.cargo/env.nu"  # For nushell
# rustc 1.91.0-nightly (040a98af7 2025-08-20)
# cargo 1.91.0-nightly (71eb84f21 2025-08-17)

# %%
# %cd /content/candle/candle-examples
# Out:
# /content/candle/candle-examples

# %% [markdown]
# https://github.com/huggingface/candle/tree/main/candle-examples/examples/phi

# %%
 cargo run --example phi --release -- --model 2 \
  --prompt "A skier slides down a frictionless slope of height 40m and length 80m. What's the skier speed at the bottom?"

# %%
! cargo run --example phi --release -- --model 2 \
  --prompt "A skier slides down a frictionless slope of height 40m and length 80m. What's the skier speed at the bottom?"
# Out:
#     Updating crates.io index
#     Updating git repository `https://github.com/zackangelo/float8`
#      Locking 664 packages to latest compatible versions
#       Adding cpal v0.15.3 (available: v0.16.0)
#       Adding criterion v0.5.1 (available: v0.7.0)
#       Adding cudarc v0.16.6 (available: v0.17.2)
#       Adding enterpolation v0.2.1 (available: v0.3.0)
#       Adding fancy-regex v0.13.0 (available: v0.16.1)
#       Adding gemm v0.17.1 (available: v0.18.2)
#       Adding getrandom v0.2.16 (available: v0.3.3)
#       Adding imageproc v0.24.0 (available: v0.25.0)
#       Adding metal v0.27.0 (available: v0.32.0)
#       Adding oci-spec v0.6.7 (available: v0.6.8)
#       Adding parquet v51.0.0 (available: v56.0.0)
#       Adding pyo3 v0.22.6 (available: v0.25.1)
#       Adding pyo3-build-config v0.22.6 (available: v0.25.1)
#       Adding rubato v0.15.0 (available: v0.16.2)
#       Adding safetensors v0.4.5 (available: v0.6.2)
#       Adding thiserror v1.0.69 (available: v2.0.16)
#       Adding wasm-bindgen-futures v0.4.45 (available: v0.4.50)
#       Adding wasm-bindgen-test v0.3.45 (available: v0.3.50)
#       Adding wasm-bindgen-test-macro v0.3.45 (available: v0.3.50)
#       Adding wasm-streams v0.4.1 (available: v0.4.2)
#       Adding web-sys v0.3.70 (available: v0.3.77)
#       Adding yew v0.20.0 (available: v0.21.0)
#       Adding yew-agent v0.2.0 (available: v0.3.0)
#       Adding yoke v0.7.5 (available: v0.8.0)
#       Adding zip v1.1.4 (available: v4.4.0)
#  Downloading crates ...
#   Downloaded adler2 v2.0.1
#   Downloaded anstream v0.6.20
#   Downloaded ab_glyph_rasterizer v0.1.10
#   Downloaded ab_glyph v0.2.31
#   Downloaded anstyle v1.0.11
#   Downloaded addr2line v0.24.2
#   Downloaded anstyle-parse v0.2.7
#   Downloaded ahash v0.8.12
#   Downloaded darling_macro v0.20.11
#   Downloaded anstyle-query v1.1.4
#   Downloaded derive_builder_macro v0.20.2
#   Downloaded hyper-rustls v0.27.7
#   Downloaded icu_properties v2.0.1
#   Downloaded gemm-f64 v0.17.1
#   Downloaded console v0.15.11
#   Downloaded hyper-tls v0.6.0
#   Downloaded heck v0.5.0
#   Downloaded rustversion v1.0.22
#   Downloaded http-body-util v0.1.3
#   Downloaded rustc-demangle v0.1.26
#   Downloaded ryu v1.0.20
#   Downloaded sharded-slab v0.1.7
#   Downloaded socks v0.3.4
#   Downloaded rand_core v0.6.4
#   Downloaded tracing-attributes v0.1.30
#   Downloaded want v0.3.1
#   Downloaded zerovec-derive v0.11.1
#   Downloaded zune-core v0.4.12
#   Downloaded spm_precompiled v0.1.4
#   Downloaded unicode-normalization-alignments v0.1.12
#   Downloaded unicode_categories v0.1.1
#   Downloaded ttf-parser v0.25.1
#   Downloaded url v2.5.6
#   Downloaded webpki-roots v1.0.2
#   Downloaded wide v0.7.33
#   Downloaded zerovec v0.11.4
#   Downloaded image v0.25.6
#   Downloaded zerotrie v0.2.2
#   Downloaded zune-jpeg v0.4.20
#   Downloaded zerocopy v0.8.26
#   Downloaded openssl v0.10.73
#   Downloaded zip v1.1.4
#   Downloaded regex-syntax v0.8.5
#   Downloaded object v0.36.7
#   Downloaded nalgebra v0.32.6
#   Downloaded regex v1.11.1
#   Downloaded winnow v0.7.12
#   Downloaded rayon v1.11.0
#   Downloaded portable-atomic v1.11.1
#   Downloaded vcpkg v0.2.15
#   Downloaded ureq v2.12.1
#   Downloaded reqwest v0.12.23
#   Downloaded pulp v0.18.22
#   Downloaded libm v0.2.15
#   Downloaded unicode-width v0.2.1
#   Downloaded regex-automata v0.4.9
#   Downloaded onig_sys v69.9.1
#   Downloaded libc v0.2.175
#   Downloaded raw-cpuid v11.5.0
#   Downloaded pulp v0.21.5
#   Downloaded png v0.17.16
#   Downloaded iri-string v0.7.8
#   Downloaded idna v1.1.0
#   Downloaded tokio v1.47.1
#   Downloaded tracing-subscriber v0.3.19
#   Downloaded mio v1.0.4
#   Downloaded itertools v0.14.0
#   Downloaded imageproc v0.24.0
#   Downloaded itertools v0.12.1
#   Downloaded icu_properties_data v2.0.1
#   Downloaded unicode-segmentation v1.12.0
#   Downloaded tracing v0.1.41
#   Downloaded tokenizers v0.21.4
#   Downloaded raw-cpuid v10.7.0
#   Downloaded rand v0.9.2
#   Downloaded openssl-sys v0.9.109
#   Downloaded num-bigint v0.4.6
#   Downloaded nom v7.1.3
#   Downloaded typenum v1.18.0
#   Downloaded tower-http v0.6.6
#   Downloaded tower v0.5.2
#   Downloaded toml_edit v0.22.27
#   Downloaded tokio-util v0.7.16
#   Downloaded syn v2.0.106
#   Downloaded serde_derive v1.0.219
#   Downloaded rand_distr v0.5.1
#   Downloaded rand_distr v0.4.3
#   Downloaded rand v0.8.5
#   Downloaded memchr v2.7.5
#   Downloaded indexmap v2.10.0
#   Downloaded rayon-core v1.13.0
#   Downloaded minimal-lexical v0.2.1
#   Downloaded matrixmultiply v0.3.10
#   Downloaded zeroize v1.8.1
#   Downloaded zerofrom-derive v0.1.6
#   Downloaded zerofrom v0.1.6
#   Downloaded yoke-derive v0.8.0
#   Downloaded yoke-derive v0.7.5
#   Downloaded yoke v0.8.0
#   Downloaded yoke v0.7.5
#   Downloaded writeable v0.6.1
#   Downloaded webpki-roots v0.26.11
#   Downloaded version_check v0.9.5
#   Downloaded utf8parse v0.2.2
#   Downloaded tracing-log v0.2.0
#   Downloaded rand_chacha v0.3.1
#   Downloaded proc-macro2 v1.0.101
#   Downloaded onig v6.5.1
#   Downloaded once_cell v1.21.3
#   Downloaded log v0.4.27
#   Downloaded indicatif v0.17.11
#   Downloaded idna_adapter v1.2.1
#   Downloaded gemm-f32 v0.18.2
#   Downloaded utf8_iter v1.0.4
#   Downloaded untrusted v0.9.0
#   Downloaded unicode-ident v1.0.18
#   Downloaded ug v0.4.0
#   Downloaded try-lock v0.2.5
#   Downloaded tracing-core v0.1.34
#   Downloaded tracing-chrome v0.7.2
#   Downloaded tower-service v0.3.3
#   Downloaded tokio-rustls v0.26.2
#   Downloaded tokio-macros v2.5.0
#   Downloaded shlex v1.3.0
#   Downloaded serde_json v1.0.143
#   Downloaded serde v1.0.219
#   Downloaded rayon-cond v0.4.0
#   Downloaded rand_core v0.9.3
#   Downloaded rand_chacha v0.9.0
#   Downloaded quote v1.0.40
#   Downloaded pin-utils v0.1.0
#   Downloaded pin-project-lite v0.2.16
#   Downloaded overload v0.1.1
#   Downloaded num-rational v0.4.2
#   Downloaded native-tls v0.2.14
#   Downloaded tower-layer v0.3.3
#   Downloaded toml_datetime v0.6.11
#   Downloaded tokio-native-tls v0.3.1
#   Downloaded tinystr v0.8.1
#   Downloaded thread_local v1.1.9
#   Downloaded thiserror-impl v2.0.16
#   Downloaded thiserror-impl v1.0.69
#   Downloaded thiserror v2.0.16
#   Downloaded thiserror v1.0.69
#   Downloaded synstructure v0.13.2
#   Downloaded sync_wrapper v1.0.2
#   Downloaded subtle v2.6.1
#   Downloaded strsim v0.11.1
#   Downloaded static_assertions v1.1.0
#   Downloaded stable_deref_trait v1.2.0
#   Downloaded ring v0.17.14
#   Downloaded encoding_rs v0.8.35
#   Downloaded ppv-lite86 v0.2.21
#   Downloaded potential_utf v0.1.2
#   Downloaded pkg-config v0.3.32
#   Downloaded percent-encoding v2.3.2
#   Downloaded paste v1.0.15
#   Downloaded owned_ttf_parser v0.25.1
#   Downloaded openssl-probe v0.1.6
#   Downloaded num_enum_derive v0.7.4
#   Downloaded num_enum v0.7.4
#   Downloaded num-traits v0.2.19
#   Downloaded num v0.4.3
#   Downloaded monostate-impl v0.1.14
#   Downloaded miniz_oxide v0.8.9
#   Downloaded memmap2 v0.9.7
#   Downloaded litemap v0.8.0
#   Downloaded libloading v0.8.8
#   Downloaded lazy_static v1.5.0
#   Downloaded itoa v1.0.15
#   Downloaded is_terminal_polyfill v1.70.1
#   Downloaded ipnet v2.11.0
#   Downloaded icu_collections v2.0.0
#   Downloaded hyper-util v0.1.16
#   Downloaded csv v1.3.1
#   Downloaded socket2 v0.6.0
#   Downloaded smallvec v1.15.1
#   Downloaded slab v0.4.11
#   Downloaded simd-adler32 v0.3.7
#   Downloaded simba v0.8.1
#   Downloaded safe_arch v0.7.4
#   Downloaded rustls v0.23.31
#   Downloaded reborrow v0.5.5
#   Downloaded rawpointer v0.2.1
#   Downloaded proc-macro-crate v3.3.0
#   Downloaded option-ext v0.2.0
#   Downloaded openssl-macros v0.1.1
#   Downloaded number_prefix v0.4.0
#   Downloaded num_cpus v1.17.0
#   Downloaded num-iter v0.1.45
#   Downloaded nu-ansi-term v0.46.0
#   Downloaded mime v0.3.17
#   Downloaded macro_rules_attribute-proc_macro v0.2.2
#   Downloaded macro_rules_attribute v0.2.2
#   Downloaded icu_provider v2.0.0
#   Downloaded icu_normalizer v2.0.0
#   Downloaded icu_locale_core v2.0.0
#   Downloaded h2 v0.4.12
#   Downloaded gimli v0.31.1
#   Downloaded serde_urlencoded v0.7.1
#   Downloaded serde_plain v1.0.2
#   Downloaded seq-macro v0.3.6
#   Downloaded safetensors v0.4.5
#   Downloaded rustls-webpki v0.103.4
#   Downloaded rustls-pki-types v1.12.0
#   Downloaded num-integer v0.1.46
#   Downloaded num-complex v0.4.6
#   Downloaded monostate v0.1.14
#   Downloaded ident_case v1.0.1
#   Downloaded icu_normalizer_data v2.0.0
#   Downloaded hyper v1.7.0
#   Downloaded http v1.3.1
#   Downloaded hashbrown v0.15.5
#   Downloaded futures-util v0.3.31
#   Downloaded flate2 v1.1.2
#   Downloaded fancy-regex v0.13.0
#   Downloaded esaxx-rs v0.1.10
#   Downloaded either v1.15.0
#   Downloaded compact_str v0.9.0
#   Downloaded clap_builder v4.5.44
#   Downloaded cc v1.2.33
#   Downloaded bitflags v2.9.2
#   Downloaded backtrace v0.3.75
#   Downloaded aho-corasick v1.1.3
#   Downloaded httparse v1.10.1
#   Downloaded hf-hub v0.4.3
#   Downloaded half v2.6.0
#   Downloaded getrandom v0.3.3
#   Downloaded gemm-c64 v0.17.1
#   Downloaded futures v0.3.31
#   Downloaded darling_core v0.20.11
#   Downloaded bytes v1.10.1
#   Downloaded base64 v0.22.1
#   Downloaded base64 v0.13.1
#   Downloaded getrandom v0.2.16
#   Downloaded gemm-common v0.18.2
#   Downloaded futures-core v0.3.31
#   Downloaded futures-channel v0.3.31
#   Downloaded derive_builder v0.20.2
#   Downloaded csv-core v0.1.12
#   Downloaded crossbeam-utils v0.8.21
#   Downloaded crossbeam-epoch v0.9.18
#   Downloaded clap v4.5.45
#   Downloaded fdeflate v0.3.7
#   Downloaded crc32fast v1.5.0
#   Downloaded anyhow v1.0.99
#   Downloaded gemm-common v0.17.1
#   Downloaded gemm-c64 v0.18.2
#   Downloaded gemm-c32 v0.18.2
#   Downloaded gemm v0.18.2
#   Downloaded futures-io v0.3.31
#   Downloaded dyn-stack v0.13.0
#   Downloaded dyn-stack v0.10.0
#   Downloaded displaydoc v0.2.5
#   Downloaded derive_builder_core v0.20.2
#   Downloaded clap_derive v4.5.45
#   Downloaded bytemuck_derive v1.10.1
#   Downloaded gemm-f16 v0.18.2
#   Downloaded gemm-f16 v0.17.1
#   Downloaded futures-task v0.3.31
#   Downloaded form_urlencoded v1.2.2
#   Downloaded fnv v1.0.7
#   Downloaded darling v0.20.11
#   Downloaded cfg-if v1.0.3
#   Downloaded byteorder v1.5.0
#   Downloaded bit-vec v0.6.3
#   Downloaded bit-set v0.5.3
#   Downloaded atomic-waker v1.1.2
#   Downloaded http-body v1.0.1
#   Downloaded gemm-f64 v0.18.2
#   Downloaded gemm-f32 v0.17.1
#   Downloaded gemm-c32 v0.17.1
#   Downloaded gemm v0.17.1
#   Downloaded futures-sink v0.3.31
#   Downloaded futures-macro v0.3.31
#   Downloaded futures-executor v0.3.31
#   Downloaded foreign-types-shared v0.1.1
#   Downloaded dirs-sys v0.5.0
#   Downloaded dary_heap v0.3.7
#   Downloaded custom_derive v0.1.7
#   Downloaded conv v0.3.3
#   Downloaded colorchoice v1.0.4
#   Downloaded castaway v0.2.4
#   Downloaded byteorder-lite v0.1.0
#   Downloaded bytemuck v1.23.2
#   Downloaded autocfg v1.5.0
#   Downloaded approx v0.5.1
#   Downloaded dirs v6.0.0
#   Downloaded crossbeam-deque v0.8.6
#   Downloaded clap_lex v0.7.5
#   Downloaded bitflags v1.3.2
#   Downloaded foreign-types v0.3.2
#   Downloaded equivalent v1.0.2
#    Compiling proc-macro2 v1.0.101
#    Compiling unicode-ident v1.0.18
#    Compiling libc v0.2.175
#    Compiling quote v1.0.40
#    Compiling syn v2.0.106
#    Compiling cfg-if v1.0.3
#    Compiling autocfg v1.5.0
#    Compiling once_cell v1.21.3
#    Compiling libm v0.2.15
#    Compiling num-traits v0.2.19
#    Compiling zerocopy v0.8.26
#    Compiling bytemuck_derive v1.10.1
#    Compiling ppv-lite86 v0.2.21
#    Compiling getrandom v0.3.3
#    Compiling memchr v2.7.5
#    Compiling bytemuck v1.23.2
#    Compiling crossbeam-utils v0.8.21
#    Compiling rand_core v0.9.3
#    Compiling synstructure v0.13.2
#    Compiling paste v1.0.15
#    Compiling rand_chacha v0.9.0
#    Compiling num-complex v0.4.6
#    Compiling either v1.15.0
#    Compiling shlex v1.3.0
#    Compiling cc v1.2.33
#    Compiling crossbeam-epoch v0.9.18
#    Compiling rand v0.9.2
#    Compiling rayon-core v1.13.0
#    Compiling crossbeam-deque v0.8.6
#    Compiling zerofrom-derive v0.1.6
#    Compiling bitflags v2.9.2
#    Compiling stable_deref_trait v1.2.0
#    Compiling itoa v1.0.15
#    Compiling zerofrom v0.1.6
#    Compiling serde v1.0.219
#    Compiling reborrow v0.5.5
#    Compiling rayon v1.11.0
#    Compiling rand_distr v0.5.1
#    Compiling serde_derive v1.0.219
#    Compiling pin-project-lite v0.2.16
#    Compiling half v2.6.0
#    Compiling seq-macro v0.3.6
#    Compiling version_check v0.9.5
#    Compiling displaydoc v0.2.5
#    Compiling pkg-config v0.3.32
#    Compiling yoke-derive v0.8.0
#    Compiling yoke v0.8.0
#    Compiling futures-core v0.3.31
#    Compiling zerovec-derive v0.11.1
#    Compiling tracing-core v0.1.34
#    Compiling bytes v1.10.1
#    Compiling ryu v1.0.20
#    Compiling smallvec v1.15.1
#    Compiling bitflags v1.3.2
#    Compiling zerovec v0.11.4
#    Compiling pulp v0.21.5
#    Compiling futures-sink v0.3.31
#    Compiling crc32fast v1.5.0
#    Compiling vcpkg v0.2.15
#    Compiling serde_json v1.0.143
#    Compiling openssl-sys v0.9.109
#    Compiling raw-cpuid v11.5.0
#    Compiling dyn-stack v0.13.0
#    Compiling tokio-macros v2.5.0
#    Compiling tracing-attributes v0.1.30
#    Compiling socket2 v0.6.0
#    Compiling mio v1.0.4
#    Compiling equivalent v1.0.2
#    Compiling log v0.4.27
#    Compiling slab v0.4.11
#    Compiling hashbrown v0.15.5
#    Compiling tokio v1.47.1
#    Compiling indexmap v2.10.0
#    Compiling tracing v0.1.41
#    Compiling gemm-common v0.18.2
#    Compiling tinystr v0.8.1
#    Compiling futures-channel v0.3.31
#    Compiling raw-cpuid v10.7.0
#    Compiling pulp v0.18.22
#    Compiling dyn-stack v0.10.0
#    Compiling num-integer v0.1.46
#    Compiling getrandom v0.2.16
#    Compiling pin-utils v0.1.0
#    Compiling litemap v0.8.0
#    Compiling simd-adler32 v0.3.7
#    Compiling fnv v1.0.7
#    Compiling rustversion v1.0.22
#    Compiling writeable v0.6.1
#    Compiling object v0.36.7
#    Compiling icu_locale_core v2.0.0
#    Compiling http v1.3.1
#    Compiling gemm-common v0.17.1
#    Compiling potential_utf v0.1.2
#    Compiling zerotrie v0.2.2
#    Compiling futures-macro v0.3.31
#    Compiling icu_properties_data v2.0.1
#    Compiling futures-task v0.3.31
#    Compiling futures-io v0.3.31
#    Compiling adler2 v2.0.1
#    Compiling icu_normalizer_data v2.0.0
#    Compiling miniz_oxide v0.8.9
#    Compiling futures-util v0.3.31
#    Compiling icu_provider v2.0.0
#    Compiling icu_collections v2.0.0
#    Compiling num-bigint v0.4.6
#    Compiling toml_datetime v0.6.11
#    Compiling foreign-types-shared v0.1.1
#    Compiling percent-encoding v2.3.2
#    Compiling openssl v0.10.73
#    Compiling winnow v0.7.12
#    Compiling zeroize v1.8.1
#    Compiling rustls-pki-types v1.12.0
#    Compiling toml_edit v0.22.27
#    Compiling num-rational v0.4.2
#    Compiling foreign-types v0.3.2
#    Compiling http-body v1.0.1
#    Compiling ring v0.17.14
#    Compiling openssl-macros v0.1.1
#    Compiling httparse v1.10.1
#    Compiling native-tls v0.2.14
#    Compiling strsim v0.11.1
#    Compiling ident_case v1.0.1
#    Compiling thiserror v1.0.69
#    Compiling darling_core v0.20.11
#    Compiling icu_normalizer v2.0.0
#    Compiling icu_properties v2.0.1
#    Compiling proc-macro-crate v3.3.0
#    Compiling num-iter v0.1.45
#    Compiling tokio-util v0.7.16
#    Compiling gemm-f32 v0.18.2
#    Compiling thiserror-impl v1.0.69
#    Compiling tower-service v0.3.3
#    Compiling openssl-probe v0.1.6
#    Compiling try-lock v0.2.5
#    Compiling byteorder v1.5.0
#    Compiling anyhow v1.0.99
#    Compiling atomic-waker v1.1.2
#    Compiling h2 v0.4.12
#    Compiling want v0.3.1
#    Compiling gemm-f16 v0.18.2
#    Compiling num v0.4.3
#    Compiling num_enum_derive v0.7.4
#    Compiling idna_adapter v1.2.1
#    Compiling darling_macro v0.20.11
#    Compiling form_urlencoded v1.2.2
#    Compiling flate2 v1.1.2
#    Compiling gemm-f32 v0.17.1
#    Compiling gemm-c32 v0.18.2
#    Compiling gemm-c64 v0.18.2
#    Compiling gemm-f64 v0.18.2
#    Compiling yoke-derive v0.7.5
#    Compiling aho-corasick v1.1.3
#    Compiling num_cpus v1.17.0
#    Compiling gimli v0.31.1
#    Compiling untrusted v0.9.0
#    Compiling utf8_iter v1.0.4
#    Compiling regex-syntax v0.8.5
#    Compiling base64 v0.22.1
#    Compiling zip v1.1.4
#    Compiling regex-automata v0.4.9
#    Compiling idna v1.1.0
#    Compiling addr2line v0.24.2
#    Compiling yoke v0.7.5
#    Compiling gemm v0.18.2
#    Compiling gemm-f16 v0.17.1
#    Compiling darling v0.20.11
#    Compiling hyper v1.7.0
#    Compiling num_enum v0.7.4
#    Compiling gemm-c64 v0.17.1
#    Compiling gemm-f64 v0.17.1
#    Compiling gemm-c32 v0.17.1
#    Compiling safetensors v0.4.5
#    Compiling sync_wrapper v1.0.2
#    Compiling onig_sys v69.9.1
#    Compiling memmap2 v0.9.7
#    Compiling libloading v0.8.8
#    Compiling thiserror v2.0.16
#    Compiling rustc-demangle v0.1.26
#    Compiling tower-layer v0.3.3
#    Compiling rustls v0.23.31
#    Compiling ipnet v2.11.0
#    Compiling portable-atomic v1.11.1
#    Compiling hyper-util v0.1.16
#    Compiling tower v0.5.2
#    Compiling backtrace v0.3.75
#    Compiling ug v0.4.0
#    Compiling gemm v0.17.1
#    Compiling derive_builder_core v0.20.2
#    Compiling rustls-webpki v0.103.4
#    Compiling url v2.5.6
#    Compiling tokio-native-tls v0.3.1
#    Compiling http-body-util v0.1.3
#    Compiling webpki-roots v1.0.2
#    Compiling fdeflate v0.3.7
#    Compiling rand_core v0.6.4
#    Compiling ahash v0.8.12
#    Compiling float8 v0.2.1 (https://github.com/zackangelo/float8?branch=cudarc_0_16#03c1f5fe)
#    Compiling safe_arch v0.7.4
#    Compiling thiserror-impl v2.0.16
#    Compiling matrixmultiply v0.3.10
#    Compiling esaxx-rs v0.1.10
#    Compiling unicode-width v0.2.1
#    Compiling iri-string v0.7.8
#    Compiling utf8parse v0.2.2
#    Compiling zune-core v0.4.12
#    Compiling option-ext v0.2.0
#    Compiling subtle v2.6.1
#    Compiling minimal-lexical v0.2.1
#    Compiling bit-vec v0.6.3
#    Compiling typenum v1.18.0
#    Compiling bit-set v0.5.3
#    Compiling nom v7.1.3
#    Compiling tower-http v0.6.6
#    Compiling dirs-sys v0.5.0
#    Compiling zune-jpeg v0.4.20
#    Compiling anstyle-parse v0.2.7
#    Compiling console v0.15.11
#    Compiling wide v0.7.33
#    Compiling candle-core v0.9.1 (/content/candle/candle-core)
#    Compiling rand_chacha v0.3.1
#    Compiling png v0.17.16
#    Compiling webpki-roots v0.26.11
#    Compiling hyper-tls v0.6.0
#    Compiling derive_builder_macro v0.20.2
#    Compiling serde_urlencoded v0.7.1
#    Compiling socks v0.3.4
#    Compiling futures-executor v0.3.31
#    Compiling castaway v0.2.4
#    Compiling itertools v0.14.0
#    Compiling monostate-impl v0.1.14
#    Compiling approx v0.5.1
#    Compiling encoding_rs v0.8.35
#    Compiling rawpointer v0.2.1
#    Compiling ttf-parser v0.25.1
#    Compiling mime v0.3.17
#    Compiling overload v0.1.1
#    Compiling anstyle v1.0.11
#    Compiling colorchoice v1.0.4
#    Compiling byteorder-lite v0.1.0
#    Compiling static_assertions v1.1.0
#    Compiling lazy_static v1.5.0
#    Compiling number_prefix v0.4.0
#    Compiling unicode-segmentation v1.12.0
#    Compiling base64 v0.13.1
#    Compiling is_terminal_polyfill v1.70.1
#    Compiling anstyle-query v1.1.4
#    Compiling macro_rules_attribute-proc_macro v0.2.2
#    Compiling macro_rules_attribute v0.2.2
#    Compiling anstream v0.6.20
#    Compiling spm_precompiled v0.1.4
#    Compiling indicatif v0.17.11
#    Compiling sharded-slab v0.1.7
#    Compiling compact_str v0.9.0
#    Compiling image v0.25.6
#    Compiling nu-ansi-term v0.46.0
#    Compiling reqwest v0.12.23
#    Compiling owned_ttf_parser v0.25.1
#    Compiling simba v0.8.1
#    Compiling monostate v0.1.14
#    Compiling rayon-cond v0.4.0
#    Compiling futures v0.3.31
#    Compiling ureq v2.12.1
#    Compiling derive_builder v0.20.2
#    Compiling onig v6.5.1
#    Compiling candle-examples v0.9.1 (/content/candle/candle-examples)
#    Compiling rand v0.8.5
#    Compiling candle-nn v0.9.1 (/content/candle/candle-nn)
#    Compiling dirs v6.0.0
#    Compiling fancy-regex v0.13.0
#    Compiling regex v1.11.1
#    Compiling tracing-log v0.2.0
#    Compiling unicode-normalization-alignments v0.1.12
#    Compiling dary_heap v0.3.7
#    Compiling serde_plain v1.0.2
#    Compiling csv-core v0.1.12
#    Compiling thread_local v1.1.9
#    Compiling unicode_categories v0.1.1
#    Compiling heck v0.5.0
#    Compiling clap_lex v0.7.5
#    Compiling ab_glyph_rasterizer v0.1.10
#    Compiling custom_derive v0.1.7
#    Compiling clap_builder v4.5.44
#    Compiling conv v0.3.3
#    Compiling ab_glyph v0.2.31
#    Compiling clap_derive v4.5.45
#    Compiling tokenizers v0.21.4
#    Compiling tracing-subscriber v0.3.19
#    Compiling csv v1.3.1
#    Compiling candle-transformers v0.9.1 (/content/candle/candle-transformers)
# warning: unnecessary parentheses around closure body
#    --> candle-transformers/src/models/stable_diffusion/uni_pc.rs:326:30
#     |
# 326 |             .filter(|(_, t)| (*t == &timestep))
#     |                              ^               ^
#     |
#     = note: `#[warn(unused_parens)]` (part of `#[warn(unused)]`) on by default
# help: remove these parentheses
#     |
# 326 -             .filter(|(_, t)| (*t == &timestep))
# 326 +             .filter(|(_, t)| *t == &timestep)
#     |
#
# warning: unnecessary parentheses around closure body
#    --> candle-transformers/src/models/stable_diffusion/uni_pc.rs:933:22
#     |
# 933 |             .map(|i| (m.i((0, i))? * cofactor.i((0, i))?))
#     |                      ^                                  ^
#     |
# help: remove these parentheses
#     |
# 933 -             .map(|i| (m.i((0, i))? * cofactor.i((0, i))?))
# 933 +             .map(|i| m.i((0, i))? * cofactor.i((0, i))?)
#     |
#
# warning: unnecessary parentheses around closure body
#    --> candle-transformers/src/models/stable_diffusion/uni_pc.rs:934:52
#     |
# 934 |             .try_fold(m0.zeros_like()?, |acc, cur| (acc + cur?))?;
#     |                                                    ^          ^
#     |
# help: remove these parentheses
#     |
# 934 -             .try_fold(m0.zeros_like()?, |acc, cur| (acc + cur?))?;
# 934 +             .try_fold(m0.zeros_like()?, |acc, cur| acc + cur?)?;
#     |
#
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# hi
#    Compiling nalgebra v0.32.6
#    Compiling hf-hub v0.4.3
#    Compiling rand_distr v0.4.3
#    Compiling itertools v0.12.1
#    Compiling imageproc v0.24.0
#    Compiling tracing-chrome v0.7.2
#    Compiling clap v4.5.45
# warning: `candle-transformers` (lib) generated 4 warnings (run `cargo fix --lib -p candle-transformers` to apply 3 suggestions)
#     Finished `release` profile [optimized] target(s) in 13m 45s
#      Running `/content/candle/target/release/examples/phi --model 2 --prompt 'A skier slides down a frictionless slope of height 40m and length 80m. What'\''s the skier speed at the bottom?'`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# ..del-00001-of-00002.safetensors [00:00:35] [] 4.65 GiB/4.65 GiB 254.10 MiB/s (0s)                                                                              retrieved the files in 44.037863186s
# Running on CPU, to run on GPU, build this example with `--features cuda`
# config.json [00:00:00] [████████████████████████████████████] 735 B/735 B - (0s)loaded the model in 25.695132278s
# starting the inference loop
# A skier slides down a frictionless slope of height 40m and length 80m. What's the skier speed at the bottom?
#
# Solution:
# The potential energy of the skier is converted into kinetic energy as it slides down the slope. The formula for potential energy is mgh, where m is mass, g is acceleration due to gravity (9.8 m/s^2), and h is height. Since there's no friction, all the potential energy is converted into kinetic energy at the bottom of the slope. The formula for kinetic energy is 1/2mv^2, where v is velocity. We can equate these two formulas:
# mgh = 1/2mv^2
# Solving for v, we get:
# v = sqrt(2gh)
# Substituting the given values, we get:
# v = sqrt(2*9.8*40) = 28 m/s
# Therefore, the skier speed at the bottom of the slope is 28 m/s.
# 188 tokens generated (0.89 token/s)

# %%
! cargo run --example phi --release -- --model 2 \
  --prompt "Who is Napoleon Bonaparte?"
# Out:
# warning: unnecessary parentheses around closure body
#    --> candle-transformers/src/models/stable_diffusion/uni_pc.rs:326:30
#     |
# 326 |             .filter(|(_, t)| (*t == &timestep))
#     |                              ^               ^
#     |
#     = note: `#[warn(unused_parens)]` (part of `#[warn(unused)]`) on by default
# help: remove these parentheses
#     |
# 326 -             .filter(|(_, t)| (*t == &timestep))
# 326 +             .filter(|(_, t)| *t == &timestep)
#     |
#
# warning: unnecessary parentheses around closure body
#    --> candle-transformers/src/models/stable_diffusion/uni_pc.rs:933:22
#     |
# 933 |             .map(|i| (m.i((0, i))? * cofactor.i((0, i))?))
#     |                      ^                                  ^
#     |
# help: remove these parentheses
#     |
# 933 -             .map(|i| (m.i((0, i))? * cofactor.i((0, i))?))
# 933 +             .map(|i| m.i((0, i))? * cofactor.i((0, i))?)
#     |
#
# warning: unnecessary parentheses around closure body
#    --> candle-transformers/src/models/stable_diffusion/uni_pc.rs:934:52
#     |
# 934 |             .try_fold(m0.zeros_like()?, |acc, cur| (acc + cur?))?;
#     |                                                    ^          ^
#     |
# help: remove these parentheses
#     |
# 934 -             .try_fold(m0.zeros_like()?, |acc, cur| (acc + cur?))?;
# 934 +             .try_fold(m0.zeros_like()?, |acc, cur| acc + cur?)?;
#     |
#
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# warning: `candle-transformers` (lib) generated 4 warnings (run `cargo fix --lib -p candle-transformers` to apply 3 suggestions)
#     Finished `release` profile [optimized] target(s) in 2.15s
#      Running `/content/candle/target/release/examples/phi --model 2 --prompt 'Who is Napoleon Bonaparte?'`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# retrieved the files in 141.45902ms
# Running on CPU, to run on GPU, build this example with `--features cuda`
# loaded the model in 30.175526408s
# starting the inference loop
# Who is Napoleon Bonaparte?
# Answer: Napoleon Bonaparte was a French military and political leader who rose to prominence during the French Revolution. He became Emperor of France in 1804 and played a significant role in European history.
#
# Question 2: How did Napoleon rise to power?
# Answer: After the French Revolution, there was a period of instability and chaos in France. Napoleon saw an opportunity to seize power and took advantage of the situation by leading successful military campaigns and consolidating his authority. He eventually became Emperor of France through a coup d'état.
#
# Question 3: What were some of Napoleon's accomplishments?
# Answer: Napoleon is known for his military conquests, which expanded French territory and established him as one of the most powerful leaders in Europe. He also implemented various reforms, such as the Napoleonic Code, which standardized laws across France. Additionally, he modernized the French army and introduced new tactics that revolutionized warfare.
#
# Question 4: How did Napoleon's actions impact European history?
# Answer: Napoleon's conquests had a profound impact on Europe. He created a vast empire that stretched from Spain to Egypt, and his military campaigns reshaped the political landscape of the continent. His wars also led to significant social and economic changes in the countries he conquered.
#
# Question 5: What were some of the challenges faced by Napoleon?
# Answer: Despite his successes, Napoleon faced numerous challenges throughout his rule. He had to constantly defend his empire against rival powers, such as Britain and Russia. Additionally, internal conflicts within France, including rebellions and uprisings, posed a threat to his authority.
#
# Question 6: How did Napoleon's reign come to an end?
# Answer: Napoleon's downfall began with the Battle^C

# %%
Running on CPU, to run on GPU, build this example with `--features cuda`

# %%
# !cargo fix --lib -p candle-transformers
# Out:
#    Compiling proc-macro2 v1.0.101
#    Compiling unicode-ident v1.0.18
#    Compiling libm v0.2.15
#    Compiling autocfg v1.5.0
#    Compiling quote v1.0.40
#    Compiling syn v2.0.106
#    Compiling num-traits v0.2.19
#    Compiling libc v0.2.175
#     Checking cfg-if v1.0.3
#    Compiling getrandom v0.3.3
#    Compiling zerocopy v0.8.26
#    Compiling crossbeam-utils v0.8.21
#     Checking ppv-lite86 v0.2.21
#     Checking rand_core v0.9.3
#     Checking rand_chacha v0.9.0
#    Compiling bytemuck_derive v1.10.1
#     Checking crossbeam-epoch v0.9.18
#     Checking rand v0.9.2
#    Compiling rayon-core v1.13.0
#     Checking reborrow v0.5.5
#     Checking rand_distr v0.5.1
#     Checking bytemuck v1.23.2
#     Checking num-complex v0.4.6
#     Checking crossbeam-deque v0.8.6
#     Checking once_cell v1.21.3
#    Compiling paste v1.0.15
#     Checking half v2.6.0
#     Checking either v1.15.0
#     Checking rayon v1.11.0
#    Compiling seq-macro v0.3.6
#    Compiling version_check v0.9.5
#    Compiling pulp v0.21.5
#     Checking bitflags v2.9.2
#     Checking raw-cpuid v11.5.0
#     Checking dyn-stack v0.13.0
#     Checking bitflags v1.3.2
#     Checking raw-cpuid v10.7.0
#     Checking pulp v0.18.22
#     Checking gemm-common v0.18.2
#     Checking dyn-stack v0.10.0
#     Checking memchr v2.7.5
#     Checking gemm-common v0.17.1
#    Compiling equivalent v1.0.2
#    Compiling serde v1.0.219
#    Compiling hashbrown v0.15.5
#    Compiling serde_derive v1.0.219
#    Compiling indexmap v2.10.0
#    Compiling synstructure v0.13.2
#     Checking num-integer v0.1.46
#    Compiling toml_datetime v0.6.11
#    Compiling winnow v0.7.12
#    Compiling toml_edit v0.22.27
#    Compiling serde_json v1.0.143
#    Compiling rustversion v1.0.22
#    Compiling thiserror v1.0.69
#    Compiling proc-macro-crate v3.3.0
#     Checking num-bigint v0.4.6
#    Compiling zerofrom-derive v0.1.6
#     Checking gemm-f32 v0.18.2
#    Compiling thiserror-impl v1.0.69
#     Checking stable_deref_trait v1.2.0
#     Checking ryu v1.0.20
#     Checking itoa v1.0.15
#    Compiling crc32fast v1.5.0
#     Checking zerofrom v0.1.6
#     Checking gemm-f16 v0.18.2
#     Checking num-rational v0.4.2
#    Compiling num_enum_derive v0.7.4
#     Checking num-iter v0.1.45
#    Compiling yoke-derive v0.7.5
#     Checking gemm-f32 v0.17.1
#     Checking gemm-c64 v0.18.2
#     Checking gemm-f64 v0.18.2
#     Checking gemm-c32 v0.18.2
#     Checking tracing-core v0.1.34
#    Compiling tracing-attributes v0.1.30
#    Compiling zip v1.1.4
#     Checking pin-project-lite v0.2.16
#     Checking tracing v0.1.41
#     Checking gemm v0.18.2
#     Checking yoke v0.7.5
#     Checking gemm-f16 v0.17.1
#     Checking num_enum v0.7.4
#     Checking num v0.4.3
#     Checking safetensors v0.4.5
#     Checking memmap2 v0.9.7
#     Checking gemm-c64 v0.17.1
#     Checking gemm-f64 v0.17.1
#     Checking gemm-c32 v0.17.1
#    Compiling displaydoc v0.2.5
#     Checking num_cpus v1.17.0
#     Checking libloading v0.8.8
#     Checking ug v0.4.0
#     Checking gemm v0.17.1
#     Checking aho-corasick v1.1.3
#     Checking float8 v0.2.1 (https://github.com/zackangelo/float8?branch=cudarc_0_16#03c1f5fe)
#     Checking regex-syntax v0.8.5
#     Checking byteorder v1.5.0
#     Checking bit-vec v0.6.3
#     Checking bit-set v0.5.3
#     Checking candle-core v0.9.1 (/content/candle/candle-core)
#     Checking regex-automata v0.4.9
#     Checking candle-nn v0.9.1 (/content/candle/candle-nn)
#     Checking fancy-regex v0.13.0
#     Checking serde_plain v1.0.2
#     Checking candle-transformers v0.9.1 (/content/candle/candle-transformers)
#        Fixed candle-transformers/src/models/stable_diffusion/uni_pc.rs (3 fixes)
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# warning: `candle-transformers` (lib) generated 1 warning
#     Finished `dev` profile [unoptimized + debuginfo] target(s) in 1m 26s

# %% [markdown]
# اشرح بالعربى warning: enum `PositionEmbeddingType` is never used --> candle-transformers/src/models/debertav2.rs:44:6 | 44 | enum PositionEmbeddingType { | ^^^^^^^^^^^^^^^^^^^^^ | = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default warning: `candle-transformers` (lib) generated 1 warning Finished `dev` profile [unoptimized + debuginfo] target(s) in 1m 26s
# بالتأكيد، إليك شرح للرسالة التحذيرية باللغة العربية:
#
# warning: enum PositionEmbeddingType is never used تحذير: التعداد PositionEmbeddingType لم يتم استخدامه أبدًا
#
# هذا يعني أن هناك تعدادًا (enum) باسم PositionEmbeddingType تم تعريفه في الملف candle-transformers/src/models/debertav2.rs في السطر 44، ولكن لم يتم استخدامه فعليًا في أي جزء من الكود.
#
# = note: #[warn(dead_code)] (part of #[warn(unused)]) on by default = ملاحظة: التحذير #[warn(dead_code)] (وهو جزء من التحذير #[warn(unused)]) مُفعّل بشكل افتراضي
#
# تشير هذه الملاحظة إلى أن هذا النوع من التحذيرات (الكود غير المستخدم أو "الكود الميت") مُفعّل تلقائيًا في إعدادات بناء المشروع.
#
# warning: candle-transformers (lib) generated 1 warning تحذير: المكتبة candle-transformers أصدرت تحذيرًا واحدًا
#
# توضح هذه الرسالة أن عملية بناء المكتبة المسماة candle-transformers نتج عنها تحذير واحد.
#
# باختصار، التحذير يعني أن هناك جزءًا من الكود تم تعريفه ولكنه غير مستخدم، وهذا ليس خطأ يمنع تشغيل البرنامج، ولكنه يُعتبر ممارسة جيدة في البرمجة لإزالة الكود غير المستخدم للحفاظ على الكود نظيفًا وسهل الفهم.

# %%
# !cargo run --example rwkv --release -- --prompt "The smallest prime is "
# Out:
#    Compiling candle-transformers v0.9.1 (/content/candle/candle-transformers)
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
#    Compiling candle-examples v0.9.1 (/content/candle/candle-examples)
# warning: `candle-transformers` (lib) generated 1 warning
#     Finished `release` profile [optimized] target(s) in 2m 19s
#      Running `/content/candle/target/release/examples/rwkv --prompt 'The smallest prime is '`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# model.safetensors [00:00:51] [██████████████] 2.94 GiB/2.94 GiB 72.65 MiB/s (0s)retrieved the files in 52.257728431s
# Running on CPU, to run on GPU, build this example with `--features cuda`
# loaded the model in 6.725442114s
# The smallest prime is ϕ(2) = 2.
# The smallest composite is ϕ(3) = 3.
# The smallest perfect number is ϕ(5) = 5.
# The smallest perfect square is ϕ(4) = 4.
# The smallest perfect cube is ϕ(6) = 6.
# The smallest perfect hexagon is ϕ(7) = 7.
# The smallest perfect octagon is ϕ(8) = 8.
# The smallest perfect decagon is ϕ(9) = 9.
# The smallest perfect dodecagon is ϕ(10) = 10.
# The smallest perfect dodecahedron is ϕ(11) = 11.
# The smallest perfect icosahedron is ϕ(12) = 12.
# The smallest perfect icosidodecahedron is ϕ(13) = 13.
# The smallest perfect icosidodecahedron is ϕ(14) = 14.
# The smallest perfect icosidodecahedron is ϕ(15) = 15.
# The smallest perfect icosidodecahedron is ϕ(16) = 16.
# The smallest perfect icosidodecahedron is ϕ(17) = 17.
# The smallest perfect icosidodecahedron is ϕ(18) = 18.
# The smallest perfect icosidodecahedron is ϕ(19) = 19.
# The smallest perfect icosidodecahedron is ϕ(20) = 20.
# The smallest perfect icosidodecahedron is ϕ(21) = 21.
# The smallest perfect icosidodecahedron is ϕ(22) = 22.
# The smallest perfect icosidodecahedron is ϕ(23) = 23.
# The smallest perfect icosidodecahedron is ϕ(24) = 24.
# The smallest perfect icosidodecahedron is ϕ(25) = 25.
# The smallest perfect ic^C

# %%
# !cargo run --example rwkv --release -- --prompt "The smallest prime is "
# Out:
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# warning: `candle-transformers` (lib) generated 1 warning
#     Finished `release` profile [optimized] target(s) in 1.99s
#      Running `/content/candle/target/release/examples/rwkv --prompt 'The smallest prime is '`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# retrieved the files in 1.482319516s
# Running on CPU, to run on GPU, build this example with `--features cuda`
# loaded the model in 12.97977172s
# The smallest prime is ϕ(2) = 2.
# The smallest composite is ϕ(3) = 3.
# The smallest perfect number is ϕ(5) = 5.
# The smallest perfect square is ϕ(4) = 4.
# The smallest perfect cube is ϕ(6) = 6.^C

# %%
# !cargo run --example rwkv --release -- --prompt "Napoleon Bonaparte is "
# Out:
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# warning: `candle-transformers` (lib) generated 1 warning
#     Finished `release` profile [optimized] target(s) in 0.87s
#      Running `/content/candle/target/release/examples/rwkv --prompt 'Napoleon Bonaparte is '`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# retrieved the files in 120.683031ms
# Running on CPU, to run on GPU, build this example with `--features cuda`
# loaded the model in 9.404183158s
# Napoleon Bonaparte is
# The French Revolution is
# The American Revolution is
# The Industrial Revolution is
# The Scientific Revolution is
# The Enlightenment is
# The Age of Reason is
# The^C

# %%
/content/candle/candle-examples/examples/vit/german-shepherd.webp


/content/candle/candle-examples/examples/yolo-v8/assets/bike.jpg

# %%
# !cargo run --example vit --release -- --image /content/candle/candle-examples/examples/yolo-v8/assets/bike.jpg
# Out:
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# warning: `candle-transformers` (lib) generated 1 warning
#     Finished `release` profile [optimized] target(s) in 0.74s
#      Running `/content/candle/target/release/examples/vit --image /content/candle/candle-examples/examples/yolo-v8/assets/bike.jpg`
# Running on CPU, to run on GPU, build this example with `--features cuda`
# loaded image Tensor[dims 3, 224, 224; f32]
# model.safetensors [00:00:04] [██████████] 330.25 MiB/330.25 MiB 77.08 MiB/s (0s)model built
# unicycle, monocycle     : 22.57%
# knee pad                : 12.97%
# mountain bike, all-terrain bike, off-roader: 12.42%
# bicycle-built-for-two, tandem bicycle, tandem: 12.34%
# crash helmet            : 6.62%

# %%
# !cargo run --example quantized --release -- --prompt "The best thing about coding in rust is "
# Out:
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# warning: `candle-transformers` (lib) generated 1 warning
#    Compiling candle-examples v0.9.1 (/content/candle/candle-examples)
#     Finished `release` profile [optimized] target(s) in 24.04s
#      Running `/content/candle/target/release/examples/quantized --prompt 'The best thing about coding in rust is '`
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.80 repeat-penalty: 1.10 repeat-last-n: 64
# llama-2-7b.ggmlv3.q4_0.bin [00:00:33] [████] 3.53 GiB/3.53 GiB 113.38 MiB/s (0s)Running on CPU, to run on GPU, build this example with `--features cuda`
# loaded 291 tensors (3.79GB) in 15.39s
# params: HParams { n_vocab: 32000, n_embd: 4096, n_mult: 256, n_head: 32, n_layer: 32, n_rot: 128, ftype: 2 }
# model built
# tokenizer.json [00:00:00] [█████████████████] 1.76 MiB/1.76 MiB 19.86 MiB/s (0s)The best thing about coding in rust is 1.) as a developer, you don't have to learn yet another language, 2.) the borrow checker makes sure your code is immutable. everyone who's been through the pain of writing "someone else already has it" in java or "this list contains a double-linked list and now i'm in trouble" in c++ knows what I mean (it's easier to specify an error at compile time than to debug runtime errors!).
# likewise, rust lets you easily leverage existing libraries with its traits system. it's so much easier than java or c++, where you always have some boilerplate around it (i don't want the conflicting [extends] annotation, have to give it a name in my function signature, etc).
# the community is already a lot bigger and I've met some amazing people on slack. rust is really a passion project for many of its contributors, which isn^C

# %%
# !wget https://arxiv.org/pdf/1706.03762.pdf
# !cargo run --features cuda,pdf2image --release --example colpali -- --prompt "What is Positional Encoding" --pdf "1706.03762.pdf"
# Out:
# --2025-08-21 22:19:53--  https://arxiv.org/pdf/1706.03762.pdf
# Resolving arxiv.org (arxiv.org)... 151.101.131.42, 151.101.3.42, 151.101.67.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.131.42|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /pdf/1706.03762 [following]
# --2025-08-21 22:19:53--  https://arxiv.org/pdf/1706.03762
# Reusing existing connection to arxiv.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2215244 (2.1M) [application/pdf]
# Saving to: ‘1706.03762.pdf’
#
# 1706.03762.pdf      100%[===================>]   2.11M  --.-KB/s    in 0.1s
#
# 2025-08-21 22:19:53 (20.7 MB/s) - ‘1706.03762.pdf’ saved [2215244/2215244]
#
#  Downloading crates ...
#   Downloaded arrayvec v0.7.6
#   Downloaded bindgen_cuda v0.1.5
#   Downloaded arg_enum_proc_macro v0.3.4
#   Downloaded noop_proc_macro v0.3.0
#   Downloaded avif-serialize v0.8.6
#   Downloaded simd_helpers v0.1.0
#   Downloaded maybe-rayon v0.1.1
#   Downloaded equator-macro v0.4.2
#   Downloaded built v0.7.7
#   Downloaded aligned-vec v0.6.4
#   Downloaded pdf2image v0.1.3
#   Downloaded wasm-bindgen-macro v0.2.100
#   Downloaded wasm-bindgen-shared v0.2.100
#   Downloaded wasm-bindgen-backend v0.2.100
#   Downloaded wasm-bindgen-macro-support v0.2.100
#   Downloaded equator v0.4.2
#   Downloaded rgb v0.8.52
#   Downloaded wasm-bindgen v0.2.100
#   Downloaded imgref v1.11.0
#   Downloaded bumpalo v3.19.0
#   Downloaded v_frame v0.3.9
#   Downloaded serde_spanned v0.6.9
#   Downloaded jobserver v0.1.33
#   Downloaded glob v0.3.3
#   Downloaded bitstream-io v2.6.0
#   Downloaded ug-cuda v0.4.0
#   Downloaded ravif v0.11.20
#   Downloaded quick-error v2.0.1
#   Downloaded num-derive v0.4.2
#   Downloaded av1-grain v0.2.4
#   Downloaded profiling-procmacros v1.0.17
#   Downloaded profiling v1.0.17
#   Downloaded new_debug_unreachable v1.0.6
#   Downloaded loop9 v0.1.5
#   Downloaded cudarc v0.16.6
#   Downloaded rav1e v0.7.1
#    Compiling crossbeam-utils v0.8.21
#    Compiling libc v0.2.175
#    Compiling crossbeam-epoch v0.9.18
#    Compiling crossbeam-deque v0.8.6
#    Compiling rayon-core v1.13.0
#    Compiling either v1.15.0
#    Compiling num_cpus v1.17.0
#    Compiling glob v0.3.3
#    Compiling rayon v1.11.0
#    Compiling cudarc v0.16.6
#    Compiling bindgen_cuda v0.1.5
# ^C

# %%
#!wget https://arxiv.org/pdf/1706.03762.pdf
# !cargo run --features cpu,pdf2image --release --example colpali -- --prompt "What is Positional Encoding" --pdf "1706.03762.pdf"
# Out:
# error: the package 'candle-examples' does not contain this feature: cpu
# help: there are similarly named features: cpal, cuda, mkl, nccl

# %%
#!wget https://arxiv.org/pdf/1706.03762.pdf
# !cargo run --features pdf2image --release --example colpali -- --prompt "What is Positional Encoding" --pdf "1706.03762.pdf"
# Out:
#    Compiling image v0.25.6
#    Compiling candle-examples v0.9.1 (/content/candle/candle-examples)
# warning: enum `PositionEmbeddingType` is never used
#   --> candle-transformers/src/models/debertav2.rs:44:6
#    |
# 44 | enum PositionEmbeddingType {
#    |      ^^^^^^^^^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` (part of `#[warn(unused)]`) on by default
#
# warning: `candle-transformers` (lib) generated 1 warning
#    Compiling pdf2image v0.1.3
#    Compiling imageproc v0.24.0
#     Finished `release` profile [optimized] target(s) in 57.30s
#      Running `/content/candle/target/release/examples/colpali --prompt 'What is Positional Encoding' --pdf 1706.03762.pdf`
# avx: true, neon: false, simd128: false, f16c: true
# ..del-00001-of-00002.safetensors [00:01:36] [] 4.64 GiB/4.64 GiB 76.81 MiB/s (0s)                                                                               retrieved the files in 307ns
# Running on CPU, to run on GPU, build this example with `--features cuda`
# ^C

# %%
import os
os.environ['PATH'] += ":/root/.cargo/bin"

# !rustc --version
# !cargo --version
# Out:
# rustc 1.91.0-nightly (040a98af7 2025-08-20)
# cargo 1.91.0-nightly (71eb84f21 2025-08-17)

# %%
# %cd /content/candle
# !cargo run --features pdf2image --release --example colpali -- --prompt "What is Positional Encoding" --pdf "1706.03762.pdf"
# Out:
# /content/candle
#  Downloading crates ...
#   Downloaded alloc-stdlib v0.2.2
#   Downloaded arrow-data v51.0.0
#   Downloaded anymap2 v0.13.0
#   Downloaded anes v0.1.6
#   Downloaded arrow-buffer v51.0.0
#   Downloaded gloo-render v0.2.0
#   Downloaded ciborium-io v0.2.2
#   Downloaded gloo-utils v0.2.0
#   Downloaded gloo-timers v0.2.6
#   Downloaded boolinator v2.4.0
#   Downloaded atoi v2.0.0
#   Downloaded proc-macro-error-attr v1.0.4
#   Downloaded gloo-timers v0.3.0
#   Downloaded gloo-utils v0.1.7
#   Downloaded ciborium-ll v0.2.2
#   Downloaded gloo-storage v0.3.0
#   Downloaded is-terminal v0.4.16
#   Downloaded cast v0.3.0
#   Downloaded unindent v0.2.4
#   Downloaded gloo-render v0.1.1
#   Downloaded oorandom v11.1.5
#   Downloaded gloo-console v0.2.3
#   Downloaded serde-wasm-bindgen v0.5.0
#   Downloaded tokio-stream v0.1.17
#   Downloaded yew-agent v0.2.0
#   Downloaded arrow-select v51.0.0
#   Downloaded twox-hash v1.6.3
#   Downloaded wasm-logger v0.2.0
#   Downloaded wasm-bindgen-futures v0.4.45
#   Downloaded zstd-safe v7.2.4
#   Downloaded walkdir v2.5.0
#   Downloaded js-sys v0.3.77
#   Downloaded zstd v0.13.3
#   Downloaded lexical-write-float v0.8.5
#   Downloaded toml_edit v0.19.15
#   Downloaded yew-macro v0.20.0
#   Downloaded chrono v0.4.41
#   Downloaded yew v0.20.0
#   Downloaded target-lexicon v0.12.16
#   Downloaded gloo v0.8.1
#   Downloaded winnow v0.5.40
#   Downloaded parquet v51.0.0
#   Downloaded pyo3 v0.22.6
#   Downloaded gloo-worker v0.2.1
#   Downloaded console_error_panic_hook v0.1.7
#   Downloaded gloo-console v0.3.0
#   Downloaded syn v1.0.109
#   Downloaded lexical-parse-float v0.8.5
#   Downloaded brotli-decompressor v2.5.1
#   Downloaded gloo-dialogs v0.2.0
#   Downloaded implicit-clone v0.3.10
#   Downloaded gloo-file v0.2.3
#   Downloaded brotli v3.5.0
#   Downloaded gloo-worker v0.1.2
#   Downloaded hashbrown v0.14.5
#   Downloaded gloo-worker v0.5.0
#   Downloaded gloo-storage v0.2.2
#   Downloaded arrow-array v51.0.0
#   Downloaded itertools v0.10.5
#   Downloaded http v0.2.12
#   Downloaded criterion v0.5.1
#   Downloaded thrift v0.17.0
#   Downloaded pyo3-ffi v0.22.6
#   Downloaded lexical-util v0.8.5
#   Downloaded web-sys v0.3.70
#   Downloaded hashbrown v0.12.3
#   Downloaded gloo-net v0.3.1
#   Downloaded fancy-regex v0.14.0
#   Downloaded wasm-bindgen-test-macro v0.3.45
#   Downloaded wasm-bindgen-test v0.3.45
#   Downloaded gloo v0.11.0
#   Downloaded tinytemplate v1.2.1
#   Downloaded zstd-sys v2.0.15+zstd.1.5.7
#   Downloaded semver v1.0.26
#   Downloaded pyo3-macros-backend v0.22.6
#   Downloaded lexical-write-integer v0.8.5
#   Downloaded lexical-parse-integer v0.8.6
#   Downloaded arrow-ipc v51.0.0
#   Downloaded arrow-cast v51.0.0
#   Downloaded tiny-keccak v2.0.2
#   Downloaded gloo-dialogs v0.1.1
#   Downloaded criterion-plot v0.5.0
#   Downloaded twox-hash v2.1.1
#   Downloaded snap v1.1.1
#   Downloaded pyo3-build-config v0.22.6
#   Downloaded proc-macro-error v1.0.4
#   Downloaded prettyplease v0.1.25
#   Downloaded pin-project-internal v1.1.10
#   Downloaded pin-project v1.1.10
#   Downloaded lz4_flex v0.11.5
#   Downloaded integer-encoding v3.0.4
#   Downloaded indexmap v1.9.3
#   Downloaded iana-time-zone v0.1.63
#   Downloaded hound v3.5.1
#   Downloaded gloo-events v0.1.2
#   Downloaded ciborium v0.2.2
#   Downloaded same-file v1.0.6
#   Downloaded rustc_version v0.4.1
#   Downloaded pyo3-macros v0.22.6
#   Downloaded prokio v0.1.0
#   Downloaded ordered-float v2.10.1
#   Downloaded lexical-core v0.8.5
#   Downloaded flatbuffers v23.5.26
#   Downloaded arrow-schema v51.0.0
#   Downloaded serde-wasm-bindgen v0.6.5
#   Downloaded proc-macro-crate v1.3.1
#   Downloaded pinned v0.1.0
#   Downloaded memoffset v0.9.1
#   Downloaded indoc v2.0.6
#   Downloaded gloo-net v0.5.0
#   Downloaded gloo-history v0.2.2
#   Downloaded gloo-history v0.1.5
#   Downloaded crunchy v0.2.4
#   Downloaded bincode v1.3.3
#   Downloaded alloc-no-stdlib v2.0.4
#   Downloaded scoped-tls v1.0.1
#   Downloaded gloo-file v0.3.0
#   Downloaded bit-vec v0.8.0
#   Downloaded bit-set v0.8.0
#   Downloaded gloo-worker-macros v0.1.0
#   Downloaded const-random-macro v0.1.16
#   Downloaded const-random v0.1.18
#   Downloaded gloo-events v0.2.0
#    Compiling getrandom v0.3.3
#    Compiling jobserver v0.1.33
#    Compiling cc v1.2.33
#    Compiling rand_core v0.9.3
#    Compiling rand_chacha v0.9.0
#    Compiling rand v0.9.2
#    Compiling openssl-sys v0.9.109
#    Compiling rand_distr v0.5.1
#    Compiling getrandom v0.2.16
#    Compiling openssl v0.10.73
#    Compiling half v2.6.0
#    Compiling gemm-common v0.18.2
#    Compiling gemm-common v0.17.1
#    Compiling ring v0.17.14
#    Compiling native-tls v0.2.14
#    Compiling gemm-f32 v0.18.2
#    Compiling gemm-f16 v0.18.2
#    Compiling gemm-f32 v0.17.1
#    Compiling gemm-f64 v0.18.2
#    Compiling gemm-c32 v0.18.2
#    Compiling gemm-c64 v0.18.2
#    Compiling gemm v0.18.2
#    Compiling gemm-f16 v0.17.1
#    Compiling gemm-c64 v0.17.1
#    Compiling gemm-c32 v0.17.1
#    Compiling gemm-f64 v0.17.1
#    Compiling onig_sys v69.9.1
#    Compiling backtrace v0.3.75
#    Compiling rustls v0.23.31
#    Compiling ug v0.4.0
#    Compiling gemm v0.17.1
#    Compiling rustls-webpki v0.103.4
#    Compiling tokio-native-tls v0.3.1
#    Compiling float8 v0.2.1 (https://github.com/zackangelo/float8?branch=cudarc_0_16#03c1f5fe)
#    Compiling rand_core v0.6.4
#    Compiling bit-vec v0.8.0
#    Compiling bit-set v0.8.0
#    Compiling rand_chacha v0.3.1
#    Compiling hyper-tls v0.6.0
#    Compiling candle-core v0.9.1 (/content/candle/candle-core)
#    Compiling anyhow v1.0.99
#    Compiling reqwest v0.12.23
# ^C

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""

# Load the model on the CPU
model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True)

text = "hi"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=11, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# Encountered exception while importing bitsandbytes: No module named 'bitsandbytes'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-762250336.py in <cell line: 0>()
#      21
#      22 # Load the model on the CPU
# ---> 23 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True)
#      24 tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True)
#      25
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568         code_revision = revision
#     569     # And lastly we get the class inside our newly created module
# --> 570     final_module = get_cached_module_file(
#     571         repo_id,
#     572         module_file + ".py",
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_cached_module_file(pretrained_model_name_or_path, module_file, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, _commit_hash, **deprecated_kwargs)
#     391
#     392     # Check we have all the requirements in our environment
# --> 393     modules_needed = check_imports(resolved_module_file)
#     394
#     395     # Now we move the module inside our cached dynamic modules.
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in check_imports(filename)
#     223
#     224     if len(missing_packages) > 0:
# --> 225         raise ImportError(
#     226             "This modeling file requires the following packages that were not found in your environment: "
#     227             f"{', '.join(missing_packages)}. Run `pip install {' '.join(missing_packages)}`"
#
# ImportError: This modeling file requires the following packages that were not found in your environment: bitsandbytes. Run `pip install bitsandbytes`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Using cached bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.8.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl (61.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 9.9 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.47.0

# %%
# !pip install flash-rwkv
# Out:
# Collecting flash-rwkv
#   Downloading flash_rwkv-0.3.0-py3-none-any.whl.metadata (87 bytes)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from flash-rwkv) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->flash-rwkv) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->flash-rwkv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->flash-rwkv) (3.0.2)
# Downloading flash_rwkv-0.3.0-py3-none-any.whl (8.4 kB)
# Installing collected packages: flash-rwkv
# Successfully installed flash-rwkv-0.3.0

# %%
# !pip install ninja
# Out:
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.13.0

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""

# Load the model on the CPU
model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True)

text = "hi"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=11, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      40 try:
# ---> 41     from flash_rwkv import rwkv5_cuda_linear_attention
#      42     # Check version
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/__init__.py in <module>
# ----> 1 from .rwkv5 import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2 from .rwkv6 import Rwkv6LinearAttention, rwkv6_cuda_linear_attention
#       3
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/__init__.py in <module>
# ----> 1 from .wkv5_op import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2
#       3 __all__ = ["Rwkv5LinearAttention", "rwkv5_cuda_linear_attention"]
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in <module>
#     208
# --> 209 load_wkv5_cuda_kernel()
#     210
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in load_wkv5_cuda_kernel()
#      25             ]
# ---> 26         rwkv5_cuda_kernel = load_kernel(
#      27             name="flash_rwkv_5",
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in load(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    1680     """
# -> 1681     return _jit_compile(
#    1682         name,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in _jit_compile(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    2163
# -> 2164     return _import_module_from_library(name, build_directory, is_python_module)
#    2165
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in _import_module_from_library(module_name, path, is_python_module)
#    2631         assert spec is not None
# -> 2632         module = importlib.util.module_from_spec(spec)
#    2633         assert isinstance(spec.loader, importlib.abc.Loader)
#
# ImportError: /root/.cache/torch_extensions/py312_cu126/flash_rwkv_5/flash_rwkv_5.so: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-1956961352.py in <cell line: 0>()
#      21
#      22 # Load the model on the CPU
# ---> 23 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, device_map="auto")
#      24 tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True)
#      25
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      47         raise Exception("Your version of flash-rwkv is below 0.2.1. Please use pip install --upgrade flash-rwkv to update or install the required version.")
#      48 except ImportError:
# ---> 49     raise ImportError("The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.")
#      50 except pkg_resources.DistributionNotFound:
#      51     raise ImportError("The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.")
#
# ImportError: The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True)

text = "请介绍北京的旅游景点"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=333, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      40 try:
# ---> 41     from flash_rwkv import rwkv5_cuda_linear_attention
#      42     # Check version
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/__init__.py in <module>
# ----> 1 from .rwkv5 import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2 from .rwkv6 import Rwkv6LinearAttention, rwkv6_cuda_linear_attention
#       3
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/__init__.py in <module>
# ----> 1 from .wkv5_op import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2
#       3 __all__ = ["Rwkv5LinearAttention", "rwkv5_cuda_linear_attention"]
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in <module>
#     208
# --> 209 load_wkv5_cuda_kernel()
#     210
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in load_wkv5_cuda_kernel()
#      25             ]
# ---> 26         rwkv5_cuda_kernel = load_kernel(
#      27             name="flash_rwkv_5",
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in load(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    1680     """
# -> 1681     return _jit_compile(
#    1682         name,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in _jit_compile(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    2163
# -> 2164     return _import_module_from_library(name, build_directory, is_python_module)
#    2165
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in _import_module_from_library(module_name, path, is_python_module)
#    2631         assert spec is not None
# -> 2632         module = importlib.util.module_from_spec(spec)
#    2633         assert isinstance(spec.loader, importlib.abc.Loader)
#
# ImportError: /root/.cache/torch_extensions/py312_cu126/flash_rwkv_5/flash_rwkv_5.so: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-3632360811.py in <cell line: 0>()
#      21
#      22
# ---> 23 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
#      24 tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True)
#      25
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      47         raise Exception("Your version of flash-rwkv is below 0.2.1. Please use pip install --upgrade flash-rwkv to update or install the required version.")
#      48 except ImportError:
# ---> 49     raise ImportError("The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.")
#      50 except pkg_resources.DistributionNotFound:
#      51     raise ImportError("The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.")
#
# ImportError: The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n', '\n').replace('\n\n', '\n')
    input = input.strip().replace('\r\n', '\n').replace('\n\n', '\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""

model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, padding_side='left', pad_token="<s>")

texts = ["请介绍北京的旅游景点", "介绍一下大熊猫", "乌兰察布"]
prompts = [generate_prompt(text) for text in texts]

inputs = tokenizer(prompts, return_tensors="pt", padding=True)
outputs = model.generate(inputs["input_ids"], max_new_tokens=128, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )

for output in outputs:
    print(tokenizer.decode(output.tolist(), skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      40 try:
# ---> 41     from flash_rwkv import rwkv5_cuda_linear_attention
#      42     # Check version
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/__init__.py in <module>
# ----> 1 from .rwkv5 import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2 from .rwkv6 import Rwkv6LinearAttention, rwkv6_cuda_linear_attention
#       3
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/__init__.py in <module>
# ----> 1 from .wkv5_op import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2
#       3 __all__ = ["Rwkv5LinearAttention", "rwkv5_cuda_linear_attention"]
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in <module>
#     208
# --> 209 load_wkv5_cuda_kernel()
#     210
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in load_wkv5_cuda_kernel()
#      25             ]
# ---> 26         rwkv5_cuda_kernel = load_kernel(
#      27             name="flash_rwkv_5",
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in load(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    1680     """
# -> 1681     return _jit_compile(
#    1682         name,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in _jit_compile(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    2163
# -> 2164     return _import_module_from_library(name, build_directory, is_python_module)
#    2165
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in _import_module_from_library(module_name, path, is_python_module)
#    2631         assert spec is not None
# -> 2632         module = importlib.util.module_from_spec(spec)
#    2633         assert isinstance(spec.loader, importlib.abc.Loader)
#
# ImportError: /root/.cache/torch_extensions/py312_cu126/flash_rwkv_5/flash_rwkv_5.so: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-591724795.py in <cell line: 0>()
#      20 Assistant:"""
#      21
# ---> 22 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
#      23 tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, padding_side='left', pad_token="<s>")
#      24
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      47         raise Exception("Your version of flash-rwkv is below 0.2.1. Please use pip install --upgrade flash-rwkv to update or install the required version.")
#      48 except ImportError:
# ---> 49     raise ImportError("The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.")
#      50 except pkg_resources.DistributionNotFound:
#      51     raise ImportError("The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.")
#
# ImportError: The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Load model directly
from transformers import AutoModelForCausalLM
model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, torch_dtype="auto"),
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      40 try:
# ---> 41     from flash_rwkv import rwkv5_cuda_linear_attention
#      42     # Check version
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/__init__.py in <module>
# ----> 1 from .rwkv5 import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2 from .rwkv6 import Rwkv6LinearAttention, rwkv6_cuda_linear_attention
#       3
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/__init__.py in <module>
# ----> 1 from .wkv5_op import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2
#       3 __all__ = ["Rwkv5LinearAttention", "rwkv5_cuda_linear_attention"]
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in <module>
#     208
# --> 209 load_wkv5_cuda_kernel()
#     210
#
# /usr/local/lib/python3.12/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in load_wkv5_cuda_kernel()
#      25             ]
# ---> 26         rwkv5_cuda_kernel = load_kernel(
#      27             name="flash_rwkv_5",
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in load(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    1680     """
# -> 1681     return _jit_compile(
#    1682         name,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in _jit_compile(name, sources, extra_cflags, extra_cuda_cflags, extra_sycl_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, with_sycl, is_python_module, is_standalone, keep_intermediates)
#    2163
# -> 2164     return _import_module_from_library(name, build_directory, is_python_module)
#    2165
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in _import_module_from_library(module_name, path, is_python_module)
#    2631         assert spec is not None
# -> 2632         module = importlib.util.module_from_spec(spec)
#    2633         assert isinstance(spec.loader, importlib.abc.Loader)
#
# ImportError: /root/.cache/torch_extensions/py312_cu126/flash_rwkv_5/flash_rwkv_5.so: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-514567941.py in <cell line: 0>()
#       1 # Load model directly
#       2 from transformers import AutoModelForCausalLM
# ----> 3 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, torch_dtype="auto"),
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.12/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      47         raise Exception("Your version of flash-rwkv is below 0.2.1. Please use pip install --upgrade flash-rwkv to update or install the required version.")
#      48 except ImportError:
# ---> 49     raise ImportError("The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.")
#      50 except pkg_resources.DistributionNotFound:
#      51     raise ImportError("The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.")
#
# ImportError: The flash-rwkv package is not detected. Please install it using pip install flash-rwkv.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
